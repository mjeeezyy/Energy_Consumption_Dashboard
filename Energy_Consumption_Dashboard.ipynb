# %% [markdown]
# ***World Energy Consumption Dashboard***

# %% [markdown]
# In this project, I will be creating an interactive Data Visualization dashboard using Panel & hvplot on World Energy Consumption dataset downloaded from Kaggle. The dataset is a collection of key metrics maintained by ourworldindata.org and includes data on energy consumption, energy mix, gas mix and other relevant metrics.

# %%
# Importing the necessary libraries

import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %%
# Loading the dataset

df = pd.read_csv('World Energy Consumption.csv')

# %%
# Looking at the dataset

df
# Out:
#       iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  Afghanistan  1900                   NaN                   NaN
# 1          AFG  Afghanistan  1901                   NaN                 0.000
# 2          AFG  Afghanistan  1902                   NaN                 0.000
# 3          AFG  Afghanistan  1903                   NaN                 0.000
# 4          AFG  Afghanistan  1904                   NaN                 0.000
# ...        ...          ...   ...                   ...                   ...
# 17427      ZWE     Zimbabwe  2015               -25.013               -10.847
# 17428      ZWE     Zimbabwe  2016               -37.694               -12.257
# 17429      ZWE     Zimbabwe  2017                 8.375                 1.697
# 17430      ZWE     Zimbabwe  2018                22.555                 4.952
# 17431      ZWE     Zimbabwe  2019               -35.015                -9.422
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 17427                  NaN                  NaN                  NaN
# 17428                  NaN                  NaN                  NaN
# 17429                  NaN                  NaN                  NaN
# 17430                  NaN                  NaN                  NaN
# 17431                  NaN                  NaN                  NaN
#
#        oil_prod_change_twh  energy_cons_change_pct  ...  \
# 0                      NaN                     NaN  ...
# 1                      NaN                     NaN  ...
# 2                      NaN                     NaN  ...
# 3                      NaN                     NaN  ...
# 4                      NaN                     NaN  ...
# ...                    ...                     ...  ...
# 17427                  NaN                  -0.789  ...
# 17428                  NaN                 -14.633  ...
# 17429                  NaN                     NaN  ...
# 17430                  NaN                     NaN  ...
# 17431                  NaN                     NaN  ...
#
#        solar_elec_per_capita  solar_energy_per_capita           gdp  \
# 0                        NaN                      NaN           NaN
# 1                        NaN                      NaN           NaN
# 2                        NaN                      NaN           NaN
# 3                        NaN                      NaN           NaN
# 4                        NaN                      NaN           NaN
# ...                      ...                      ...           ...
# 17427                  0.579                      NaN  2.503057e+10
# 17428                  0.641                      NaN  2.515176e+10
# 17429                  0.773                      NaN           NaN
# 17430                  0.970                      NaN           NaN
# 17431                  0.956                      NaN           NaN
#
#        wind_share_elec  wind_cons_change_pct  wind_share_energy  \
# 0                  NaN                   NaN                NaN
# 1                  NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
# 3                  NaN                   NaN                NaN
# 4                  NaN                   NaN                NaN
# ...                ...                   ...                ...
# 17427              0.0                   NaN                NaN
# 17428              0.0                   NaN                NaN
# 17429              0.0                   NaN                NaN
# 17430              0.0                   NaN                NaN
# 17431              0.0                   NaN                NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 17427                   NaN               NaN                   0.0
# 17428                   NaN               NaN                   0.0
# 17429                   NaN               NaN                   0.0
# 17430                   NaN               NaN                   0.0
# 17431                   NaN               NaN                   0.0
#
#        wind_energy_per_capita
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17427                     NaN
# 17428                     NaN
# 17429                     NaN
# 17430                     NaN
# 17431                     NaN
#
# [17432 rows x 122 columns]

# %% [markdown]
# As we can see above, there is a lot of missing information in the dataset and it will replaced by 0. For example, annual change in coal production has missing values from the year 1900 to 1949 in Afghanistan.

# %%
# Dataset description...

df.describe(include='all')
# Out:
#         iso_code country          year  coal_prod_change_pct  \
# count    17432.0   17432  17432.000000          17432.000000
# unique     217.0     242           NaN                   NaN
# top          0.0  Norway           NaN                   NaN
# freq      1802.0     121           NaN                   NaN
# mean         NaN     NaN   1973.094367              8.896576
# std          NaN     NaN     34.333995            455.719085
# min          NaN     NaN   1900.000000           -100.000000
# 25%          NaN     NaN   1946.000000              0.000000
# 50%          NaN     NaN   1983.000000              0.000000
# 75%          NaN     NaN   2002.000000              0.000000
# max          NaN     NaN   2020.000000          44965.754000
#
#         coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# count           17432.000000         1.743200e+04         17432.000000
# unique                   NaN                  NaN                  NaN
# top                      NaN                  NaN                  NaN
# freq                     NaN                  NaN                  NaN
# mean                5.245954         5.359643e+13             6.506119
# std               104.720036         7.076353e+15            57.917151
# min             -2326.870000        -1.000000e+02         -1054.320000
# 25%                 0.000000         0.000000e+00             0.000000
# 50%                 0.000000         0.000000e+00             0.000000
# 75%                 0.000000         0.000000e+00             0.000000
# max              3060.593000         9.342930e+17          2112.975000
#
#         oil_prod_change_pct  oil_prod_change_twh  energy_cons_change_pct  ...  \
# count          17432.000000         17432.000000              17432.0000  ...
# unique                  NaN                  NaN                     NaN  ...
# top                     NaN                  NaN                     NaN  ...
# freq                    NaN                  NaN                     NaN  ...
# mean               6.824078             8.860683                     inf  ...
# std              205.374833           119.227211                     NaN  ...
# min             -100.000000         -2239.737000                -92.6320  ...
# 25%                0.000000             0.000000                  0.0000  ...
# 50%                0.000000             0.000000                  0.0000  ...
# 75%                0.000000             0.000000                  3.4455  ...
# max            25500.000000          2790.614000                     inf  ...
#
#         solar_energy_per_capita           gdp  wind_share_elec  \
# count              17432.000000  1.743200e+04     17432.000000
# unique                      NaN           NaN              NaN
# top                         NaN           NaN              NaN
# freq                        NaN           NaN              NaN
# mean                   7.229193  3.249705e+11         0.350650
# std                   64.670000  3.173906e+12         2.225081
# min                    0.000000  0.000000e+00         0.000000
# 25%                    0.000000  0.000000e+00         0.000000
# 50%                    0.000000  8.057833e+09         0.000000
# 75%                    0.000000  6.627885e+10         0.000000
# max                 1763.675000  1.070000e+14        56.338000
#
#         wind_cons_change_pct  wind_share_energy  wind_cons_change_twh  \
# count           17432.000000       17432.000000          17432.000000
# unique                   NaN                NaN                   NaN
# top                      NaN                NaN                   NaN
# freq                     NaN                NaN                   NaN
# mean               27.747624           0.084885              0.522214
# std              2035.417804           0.679687              8.408286
# min              -100.000000           0.000000            -10.409000
# 25%                 0.000000           0.000000              0.000000
# 50%                 0.000000           0.000000              0.000000
# 75%                 0.000000           0.000000              0.000000
# max            242384.843000          20.660000            428.736000
#
#         wind_consumption  wind_elec_per_capita  wind_energy_per_capita  \
# count       17432.000000          17432.000000            17432.000000
# unique               NaN                   NaN                     NaN
# top                  NaN                   NaN                     NaN
# freq                 NaN                   NaN                     NaN
# mean            3.711405             16.916486               32.978035
# std            63.170366            120.293067              261.111136
# min             0.000000              0.000000                0.000000
# 25%             0.000000              0.000000                0.000000
# 50%             0.000000              0.000000                0.000000
# 75%             0.000000              0.000000                0.000000
# max          3540.051000           2825.425000             6928.363000
#
#         gdp_per_capita
# count     17432.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean       5651.792155
# std       11310.843536
# min           0.000000
# 25%           0.000000
# 50%        1435.652952
# 75%        6110.956063
# max      225016.685714
#
# [11 rows x 123 columns]

# %%
# Looking at the list of columns in the dataset

df.columns
# Out:
# Index(['iso_code', 'country', 'year', 'coal_prod_change_pct',
#        'coal_prod_change_twh', 'gas_prod_change_pct', 'gas_prod_change_twh',
#        'oil_prod_change_pct', 'oil_prod_change_twh', 'energy_cons_change_pct',
#        ...
#        'solar_elec_per_capita', 'solar_energy_per_capita', 'gdp',
#        'wind_share_elec', 'wind_cons_change_pct', 'wind_share_energy',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_energy_per_capita'],
#       dtype='object', length=122)

# %% [markdown]
# ***Cleaning the dataset***

# %%
# Filling NAN's with 0

df = df.fillna(0)

# Creating new column for the dashboard by dividing gdp over population

df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %% [markdown]
# ***Renaming the country column***

# %%
# Renaming the country column to continents since the dashboard will be focusing on continent information

df = df.rename(columns={'country': 'Continents'})

# %% [markdown]
# ***Making the dataframe interactive***

# %%
# Transforming the dataframe pipeline from static to interactive

idf = df.interactive()

# %% [markdown]
# ***Gas production over time by continent***

# %%
# Creating panel widgets and year slider

year_slider = pn.widgets.IntSlider(name='Year Slider', start=1900, end=2019, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2019, name='Year Slider', start=1900, step=5, value=1850)

# %%
# Radio button widget for gas production measures

yaxis_gp = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['gas_prod_change_pct', 'gas_prod_change_twh',],
    button_type='success'
)

# %% [markdown]
# ***Connecting the Data pipeline with the widgets***

# %%
# Everytime the widgets change the underlying data will also change/get updated

continents = ['Africa', 'Asia Pacific', 'Europe', 'Europe Other', 'Middle East', 'North America', 
             'Other Asia & Pacific', 'Other Middle East', 'South & Central America', 'World']

gp_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country','year'])[yaxis_gp].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
# Looking at the created gas production pipeline

gp_pipeline
# Out:
# <div id='5433'>
#   <div class="bk-root" id="1450022a-70c6-4989-8ac5-726f01a738c3" data-root-id="5433"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"7ba53e94-a8fc-426d-8db9-a635e48a7a49":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"active":0,"button_type":"success","labels":["gas_prod_change_pct","gas_prod_change_twh"],"margin":[5,10,5,10]},"id":"5438","type":"RadioButtonGroup"},{"attributes":{"children":[{"id":"5434"}],"margin":[0,0,0,0],"name":"Row54770"},"id":"5433","type":"Row"},{"attributes":{"children":[{"id":"5437"},{"id":"5438"}],"margin":[0,0,0,0],"name":"Column54623"},"id":"5436","type":"Column"},{"attributes":{"end":2019,"margin":[5,10,5,10],"start":1900,"step":5,"title":"Year Slider","value":1990},"id":"5437","type":"Slider"},{"attributes":{"children":[{"id":"5441"}],"margin":[0,0,0,0],"name":"Row54628"},"id":"5440","type":"Row"},{"attributes":{"children":[{"id":"5435"},{"id":"5440"}],"margin":[0,0,0,0],"name":"Column54769"},"id":"5434","type":"Column"},{"attributes":{"client_comm_id":"6f70a0e353c544fa9b31f2a5cdb572aa","comm_id":"a5ac2856a96b4853bf7a5f95c5c45840","plot_id":"5433"},"id":"5442","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame54765","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;gas_prod_change_pct&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Africa&lt;/td&gt;\n      &lt;td&gt;1900& ...

# %%
# Creating one of the charts for the dashboard

gp_plot = gp_pipeline.hvplot(x = 'year', by='country', y=yaxis_gp, line_width=2, title="Gas Production by continents")
gp_plot
# Out:
# <div id='41486'>
#   <div class="bk-root" id="71ed6f27-1932-47a2-aff1-3536f7561a7b" data-root-id="41486"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e11a54b7-c3e4-411b-9544-0df94f1e32c3":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"line_color":"#e5ae38","line_width":2,"x":{"field":"year"},"y":{"field":"gas_prod_change_pct"}},"id":"41606","type":"Line"},{"attributes":{"active_drag":{"id":"41522"},"active_scroll":{"id":"41523"},"tools":[{"id":"41495"},{"id":"41521"},{"id":"41522"},{"id":"41523"},{"id":"41524"},{"id":"41525"}]},"id":"41527","type":"Toolbar"},{"attributes":{"line_alpha":0.2,"line_color":"#17becf","line_width":2,"x":{"field":"year"},"y":{"field":"gas_prod_change_pct"}},"id":"41666","type":"Line"},{"attributes":{"label":{"value":"Africa"},"renderers":[{"id":"41546"}]},"id":"41559","type":"LegendItem"},{"attributes":{"line_color":"#9467bd","line_width":2,"x":{"field":"year"},"y":{"field":"gas_prod_change_pct"}},"id":"41694","type":"Line"},{"attributes":{"line_alpha":0.1,"line_color":"#e5ae38","line_width":2,"x":{"field":"year"},"y":{"field":"gas_prod_change_pct"}},"id":"41587","type":"Line"},{"attributes":{"coordinates":null,"data_source":{"id":"41723"},"glyph":{"id":"41726"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"41728"},"nonselection_glyph":{"id":"41727"},"selection_glyph":{"id":"41756"},"view":{"id":"41730"}},"id":"41729","type":"GlyphRenderer"},{"attributes":{"coordinates":null,"data_source":{"id":"41633"},"glyph":{"id":"41636"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"41638"},"nonselection_glyph":{"id":"41637"},"selection_glyph":{"id":"41660"},"view":{"id":"41640"}},"id":"41639","type":"Gly ...

# %%
# Creating a table for the dashboard

gp_table = gp_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')
gp_table
# Out:
# <div id='40424'>
#   <div class="bk-root" id="5f5b2743-c381-4f46-83ed-95ea508f5a9b" data-root-id="40424"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ea76a80e-6ac6-4432-9f62-95383c111d31":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"40441","type":"StringEditor"},{"attributes":{"client_comm_id":"1da06178a91b4d8baec9bfdaaed8d036","comm_id":"aa0626409c8e496d9cd681a0a4765783","plot_id":"40424"},"id":"40463","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer167095","sizing_mode":"stretch_width"},"id":"40430","type":"Spacer"},{"attributes":{},"id":"40446","type":"IntEditor"},{"attributes":{"children":[{"id":"40425"}],"margin":[0,0,0,0],"name":"Row167098"},"id":"40424","type":"Row"},{"attributes":{"columns":[{"id":"40437"},{"id":"40442"},{"id":"40447"},{"id":"40452"}],"configuration":{"columns":[{"field":"index","sorter":"number"},{"field":"country"},{"field":"year","sorter":"number"},{"field":"gas_prod_change_pct","sorter":"number"}],"dataTree":false,"selectable":true},"indexes":["index"],"layout":"fit_data_table","margin":[5,10,5,10],"max_page":65,"name":"","page":1,"page_size":10,"pagination":"remote","select_mode":true,"selectable_rows":null,"sizing_mode":"stretch_width","source":{"id":"40432"},"styles":{"data":{},"id":"ad895cdd73704f86af0cdc76c2dabca1"},"subscribed_events":["cell-click","table-edit"],"theme_url":"https://cdn.jsdelivr.net/npm/@holoviz/panel@0.14.2/dist/bundled/datatabulator/tabulator-tables@5.3.2/dist/css/"},"id":"40455","type":"panel.models.tabulator.DataTabulator"},{"attributes":{},"id":"40440","type":"StringFormatter"},{"attributes":{},"id":"40436","type":"CellE ...
#     var render_items = [{"docid":"ea76a80e-6ac6-4432-9f62-95383c111d31","root_ids":["40424"],"roots":{"40424":"5f5b2743-c381-4f46-83ed-95ea508f5a9b"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined) && (root['Tabulator'] !== undefined) && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }

# %%
# Creating the scatterplot for the dashboard and another pipeline because the dataset has to be filtered by...
# ...the exact year and also only countries.

gp_gdp_sp_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['gas_prod_change_pct'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
# Visualizing the scatterplot for the dashboard

gp_gdp_sp = gp_gdp_sp_pipeline.hvplot(x='gdp_per_capita',
                                      y='gas_prod_change_pct',
                                      size=80, kind="scatter",
                                      alpha=0.7,
                                      legend=False,
                                      height=500,
                                      width=500,
                                     color="#CE93D8")
gp_gdp_sp
# Out:
# <div id='40225'>
#   <div class="bk-root" id="b3d0c742-340b-470c-b057-de6a2cb321dc" data-root-id="40225"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e3b4aa60-c161-414e-b8ab-208f1f9efea3":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"axis":{"id":"40247"},"coordinates":null,"dimension":1,"grid_line_color":null,"group":null,"ticker":null},"id":"40250","type":"Grid"},{"attributes":{},"id":"40255","type":"ResetTool"},{"attributes":{"axis_label":"gas_prod_change_pct","coordinates":null,"formatter":{"id":"40277"},"group":null,"major_label_policy":{"id":"40278"},"ticker":{"id":"40248"}},"id":"40247","type":"LinearAxis"},{"attributes":{},"id":"40241","type":"LinearScale"},{"attributes":{},"id":"40252","type":"PanTool"},{"attributes":{},"id":"40277","type":"BasicTickFormatter"},{"attributes":{},"id":"40274","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#CE93D8"},"hatch_alpha":{"value":0.1},"hatch_color":{"value":"#CE93D8"},"line_alpha":{"value":0.7},"line_color":{"value":"#CE93D8"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"gas_prod_change_pct"}},"id":"40268","type":"Scatter"},{"attributes":{"data":{"gas_prod_change_pct":{"__ndarray__":"...","dtype":"float64","order":"little","shape":[231]},"gdp_per_capita":{"__ndarray__":"...","dtype":"float64","order":"little","shape":[231]}},"selected":{"id":"40265"},"selection_policy":{"id":"40290"}},"id":"40264","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","coordinates":null,"fill_alpha":0.5,"fill_color":"lightgrey","group":null,"left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"b ...

# %% [markdown]
# ***Different Energy Consumption by Continents***

# %% [markdown]
# For the last section in the dashboard, I will create a new radio button group then select different energy consumption variables to visualize. The selected energy consumptions would be compared to different continents for the chart, hence a a third and final pipeline will be created.

# %%
# Creating the radio button and 3rd pipeline

yaxis_energy_consumption = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['gas_electricity', 'hydro_electricity', 'oil_electricity'],
    button_type='success'
)

continents_wo_world = ['Africa', 'Asia Pacific', 'Europe', 'Middle East', 'North America', 'South & Central America']

energy_consumption_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_wo_world))
    ]
    .groupby(['year', 'country'])[yaxis_energy_consumption].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
# Visualizing the energy consumption bar plot

energy_consumption_bar_plot = energy_consumption_bar_pipeline.hvplot(kind='bar',
                                                                     x='country',
                                                                     y=yaxis_energy_consumption,
                                                                     title='Energy Consumption by Continents',
                                                                    color="#CE93D8")

energy_consumption_bar_plot
# Out:
# <div id='37431'>
#   <div class="bk-root" id="b5928a85-360f-4e4c-b7fd-8beb55d44887" data-root-id="37431"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e912bad7-4759-415f-86b9-8392c13c826f":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"37458","type":"PanTool"},{"attributes":{"end":459.5363,"reset_end":459.5363,"reset_start":0.0,"tags":[[["oil_electricity","oil_electricity",null]]]},"id":"37439","type":"Range1d"},{"attributes":{"end":2019,"margin":[5,10,5,10],"start":1900,"step":5,"title":"Year Slider","value":2000},"id":"37435","type":"Slider"},{"attributes":{"source":{"id":"37470"}},"id":"37477","type":"CDSView"},{"attributes":{"children":[{"id":"37435"},{"id":"37436"}],"margin":[0,0,0,0],"name":"Column155230"},"id":"37434","type":"Column"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#CE93D8"},"hatch_alpha":{"value":0.1},"hatch_color":{"value":"#CE93D8"},"line_alpha":{"value":0.1},"top":{"field":"oil_electricity"},"width":{"value":0.8},"x":{"field":"country"}},"id":"37474","type":"VBar"},{"attributes":{},"id":"37461","type":"ResetTool"},{"attributes":{},"id":"37471","type":"Selection"},{"attributes":{"children":[{"id":"37433"},{"id":"37441"}],"margin":[0,0,0,0],"name":"Column155241"},"id":"37432","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer155234","sizing_mode":"stretch_width"},"id":"37437","type":"Spacer"},{"attributes":{"coordinates":null,"data_source":{"id":"37470"},"glyph":{"id":"37473"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"37475"},"nonselection_glyph":{"id":"37474"},"selection_glyph":{"id":"37478"},"view":{"id":"37477"}},"id":"37476","type":"GlyphRenderer"},{"attr ...

# %% [markdown]
# ***Creating the dashboard***

# %%
# Using the FastList Template from Panel for the layout of the dashboard

template = pn.template.FastListTemplate(
    title='World Energy Consumption Dashboard',
    sidebar=[pn.pane.Markdown("# Energy Consumption by Different Continents"),
             pn.pane.Markdown("### Energy consumption pertains to the energy used while inhabiting a building, manufacturing or performing an action. According to The World Counts, global energy consumption has increased by about a third and is projected to continue to grow in the foreseeable future. Although C02 emission is on the rise, it is imperative that global industries as well as human beings transit toward green/renewable energy solutions."),
             pn.pane.PNG('wind_turbine.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Controls"),
             year_slider],
    main=[pn.Row(pn.Column(yaxis_gp,
                           gp_plot.panel(width=600, height=500), margin=(1,25)), gp_table.panel(width=800)),
          pn.Row(pn.Column(gp_gdp_sp.panel(width=600), margin=(0,25)),
                 pn.Column(yaxis_energy_consumption, energy_consumption_bar_plot.panel(width=800)))],
    accent_base_color="#CE93D8",
    header_background="#CE93D8",
    theme="dark",
    theme_toggle=True
)

# Showing the template

template.show()
